# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\late4\Downloads\관서별 5대범죄 발생 및 검거.xlsx')

# %%
print(df)
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %%
category_map = {'서대문서': '서대문구', '수서서': '강남구', '강서서': '강서구', '서초서': '서초구',
'서부서': '은평구', '중부서': '중구', '종로서': '종로구', '남대문서': '중구',
'혜화서': '종로구', '용산서': '용산구', '성북서': '성북구', '동대문서': '동대문구',
'마포서': '마포구', '영등포서': '영등포구', '성동서': '성동구', '동작서': '동작구',
'광진서': '광진구', '강북서': '강북구', '금천서': '금천구', '중랑서': '중랑구',
'강남서': '강남구', '관악서': '관악구', '강동서': '강동구', '종암서': '성북구', 
'구로서': '구로구', '양천서': '양천구', '송파서': '송파구', '노원서': '노원구', 
'방배서': '서초구', '은평서': '은평구', '도봉서': '도봉구'}

# %%
df['관서명'] = df['구별'].map(category_map).fillna('구 없음')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구별'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['관서명'] = df['구별'].map(category_map).fillna('구 없음')
#
# ...

# %%
df['구별'] = df['관서명'].map(category_map).fillna('구 없음')

# %%
print(df)
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %%
df.drop(0, inplace=True)

# %%
print(df)
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# 12   동작서    4074    2397       5       5       9       5     285     139
# ...

# %%
pivot_df = pd.pivot_table(df, index='구별', values=['소계(발생)','소계(검거)','살인(발생)','살인(검거)','강도(발생)','강도(검거)','강간(발생)','강간(검거)','절도(발생)','절도(검거)','폭력(발생)','폭력(검거)'], aggfunc='sum')

# %%
print(pivot_df)
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      349     449      18      21      10      13    5732    8617    1650
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# 동대문구     146     173      13      13       5       5    3205    4720     814
# ...

# %%
small_df = df['구별'].isin(['강간(검거)','강간(발생)'],['강도(검거)','강도(발생)'],['살인(검거)','살인(발생)'],['소계(검거)','소계(발생)'],['절도(검거)','절도(발생)'],['폭력(검거)','폭력(발생)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 small_df = df['구별'].isin(['강간(검거)','강간(발생)'],['강도(검거)','강도(발생)'],['살인(검거)','살인(발생)'],['소계(검거)','소계(발생)'],['절도(검거)','절도(발생)'],['폭력(검거)','폭력(발생)'])
#
# TypeError: Series.isin() takes 2 positional arguments but 7 were given

# %%
small_df_1 = df[['구별'].isin(['강간(검거)','강간(발생)'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 small_df_1 = df[['구별'].isin(['강간(검거)','강간(발생)'])]
#
# AttributeError: 'list' object has no attribute 'isin'

# %%
df['강간검거율'] = (df['강간(검거)'] / df['강간(발생)']) * 100

# %%
df['강도검거율'] = (df['강도(검거)'] / df['강도(발생)']) * 100
df['살인검거율'] = (df['살인(검거)'] / df['살인(발생)']) * 100
df['소계검거율'] = (df['소계(검거)'] / df['소계(발생)']) * 100
df['절도검거율'] = (df['절도(검거)'] / df['절도(발생)']) * 100
df['폭력검거율'] = (df['폭력(검거)'] / df['폭력(발생)']) * 100

# %%
print(df)
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# 12   동작서    4074    2397       5       5       9       5     285     139
# ...

# %%
del df.['강간검거율(%)','강간(검거)','강도(검거)','살인(검거)','절도(검거)','폭력(검거)','소계(발생)','소계(검거)']
# Out:
#   Cell In[85], line 1
#     del df.['강간검거율(%)','강간(검거)','강도(검거)','살인(검거)','절도(검거)','폭력(검거)','소계(발생)','소계(검거)']
#            ^
# SyntaxError: invalid syntax

# %%
df.drop(columns = ['강간검거율(%)','강간(검거)','강도(검거)','살인(검거)','절도(검거)','폭력(검거)','소계(발생)','소계(검거)'])
# Out:
#      관서명  살인(발생)  강도(발생)  강간(발생)  절도(발생)  폭력(발생)    구별       강간검거율  \
# 1    중부서       2       3     105    1395    1355    중구   61.904762
# 2    종로서       3       6     115    1070    1278   종로구   85.217391
# 3   남대문서       1       6      65    1153     869    중구   70.769231
# 4   서대문서       2       5     154    1812    2056  서대문구   80.519481
# 5    혜화서       3       5      96    1114    1015   종로구   65.625000
# 6    용산서       5      14     194    1557    2050   용산구   89.175258
# 7    성북서       2       2      86     953    1194   성북구   82.558140
# 8   동대문서       5      13     173    1981    2548  동대문구   84.393064
# 9    마포서       8      14     294    2555    2983   마포구   84.013605
# 10  영등포서      14      22     295    2964    3572  영등포구   62.033898
# 11   성동서       4       9     126    1607    1612   성동구   94.444444
# 12   동작서       5       9     285    1865    1910   동작구   48.771930
# 13   광진서       4      14     240    3026    2625   광진구   91.666667
# ...

# %%
df.rename(columns = {'강간(발생)':'강간','강도(발생)':'강도','살인(발생)':'살인','절도(발생)':'절도','폭력(발생)':'폭력'})
# Out:
#      관서명  살인  강도   강간    절도    폭력    구별       강간검거율       강도검거율       살인검거율  \
# 1    중부서   2   3  105  1395  1355    중구   61.904762   66.666667  100.000000
# 2    종로서   3   6  115  1070  1278   종로구   85.217391   83.333333  100.000000
# 3   남대문서   1   6   65  1153   869    중구   70.769231   66.666667    0.000000
# 4   서대문서   2   5  154  1812  2056  서대문구   80.519481   80.000000  100.000000
# 5    혜화서   3   5   96  1114  1015   종로구   65.625000   80.000000   66.666667
# 6    용산서   5  14  194  1557  2050   용산구   89.175258  100.000000  100.000000
# 7    성북서   2   2   86   953  1194   성북구   82.558140   50.000000  100.000000
# 8   동대문서   5  13  173  1981  2548  동대문구   84.393064  100.000000  100.000000
# 9    마포서   8  14  294  2555  2983   마포구   84.013605   71.428571  100.000000
# 10  영등포서  14  22  295  2964  3572  영등포구   62.033898   90.909091   85.714286
# 11   성동서   4   9  126  1607  1612   성동구   94.444444   88.888889  100.000000
# ...

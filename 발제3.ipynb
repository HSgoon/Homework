# %%
df.rename(columns = {'강간(발생)':'강간','강도(발생)':'강도','살인(발생)':'살인','절도(발생)':'절도','폭력(발생)':'폭력'})
# Out:
#      관서명  살인  강도   강간    절도    폭력    구별       강간검거율       강도검거율       살인검거율  \
# 1    중부서   2   3  105  1395  1355    중구   61.904762   66.666667  100.000000
# 2    종로서   3   6  115  1070  1278   종로구   85.217391   83.333333  100.000000
# 3   남대문서   1   6   65  1153   869    중구   70.769231   66.666667    0.000000
# 4   서대문서   2   5  154  1812  2056  서대문구   80.519481   80.000000  100.000000
# 5    혜화서   3   5   96  1114  1015   종로구   65.625000   80.000000   66.666667
# 6    용산서   5  14  194  1557  2050   용산구   89.175258  100.000000  100.000000
# 7    성북서   2   2   86   953  1194   성북구   82.558140   50.000000  100.000000
# 8   동대문서   5  13  173  1981  2548  동대문구   84.393064  100.000000  100.000000
# 9    마포서   8  14  294  2555  2983   마포구   84.013605   71.428571  100.000000
# 10  영등포서  14  22  295  2964  3572  영등포구   62.033898   90.909091   85.714286
# 11   성동서   4   9  126  1607  1612   성동구   94.444444   88.888889  100.000000
# ...
